# %%
# !pyinstaller -F 关键词可视化.py
# Out:
# 95 INFO: PyInstaller: 4.0
# 95 INFO: Python: 3.7.9 (conda)
# 95 INFO: Platform: Windows-10-10.0.18362-SP0
# 95 INFO: wrote d:\work\关键词可视化\关键词可视化.spec
# 99 INFO: UPX is not available.
# 103 INFO: Extending PYTHONPATH with paths
# ['d:\\work\\关键词可视化', 'd:\\work\\关键词可视化']
# 147 INFO: checking Analysis
# 147 INFO: Building Analysis because Analysis-00.toc is non existent
# 147 INFO: Initializing module dependency graph...
# 155 INFO: Caching module graph hooks...
# 167 INFO: Analyzing base_library.zip ...
# 2318 INFO: Processing pre-find module path hook distutils from 'd:\\app\\anaconda\\envs\\py37\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 2318 INFO: distutils: retargeting to non-venv dir 'd:\\app\\anaconda\\envs\\py37\\lib'
# 3858 INFO: Caching module dependency graph...
# 3986 INFO: running Analysis Analysis-00.toc
# 4002 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
# ...
