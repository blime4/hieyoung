# %%
import pandas as pd

# %%
df = pd.read_excel("./final.xlsx")
df.head()
# Out:
#         标题-1字  频率-0             标题-2字  频率-2                   标题-3字  频率-4  \
# 0       cable  29.0  cable management  23.0  great cable management   7.0
# 1       stars  27.0        five stars  22.0   cable management tool   2.0
# 2       great  26.0       great cable   7.0                     NaN   NaN
# 3  management  23.0      easy install   6.0                     NaN   NaN
# 4        five  22.0        four stars   5.0                     NaN   NaN
#
#     评论-1字  频率-6             评论-2字  频率-8                    评论-3字  频率-10
# 0    desk    57  cable management  25.0  cable management system    3.0
# 1  cables    47      easy install  19.0     product easy install    3.0
# 2   cable    40       power strip  11.0    cable management easy    2.0
# 3   great    39     great product   9.0       placed power strip    2.0
# 4    easy    37   surge protector   7.0        desk easy install    2.0

# %%
dff = df

# %%
dff
# Out:
#           标题-1字  频率-0             标题-2字  频率-2                   标题-3字  频率-4  \
# 0         cable  29.0  cable management  23.0  great cable management   7.0
# 1         stars  27.0        five stars  22.0   cable management tool   2.0
# 2         great  26.0       great cable   7.0                     NaN   NaN
# 3    management  23.0      easy install   6.0                     NaN   NaN
# 4          five  22.0        four stars   5.0                     NaN   NaN
# ..          ...   ...               ...   ...                     ...   ...
# 252         NaN   NaN               NaN   NaN                     NaN   NaN
# 253         NaN   NaN               NaN   NaN                     NaN   NaN
# 254         NaN   NaN               NaN   NaN                     NaN   NaN
# 255         NaN   NaN               NaN   NaN                     NaN   NaN
# 256         NaN   NaN               NaN   NaN                     NaN   NaN
#
# ...

# %%
dff[dff.columns[1::2].tolist()],dff[dff.columns[0::2].tolist()]=dff[dff.columns[0::2].tolist()],dff[dff.columns[1::2].tolist()]
dff
# Out:
#      标题-1字        频率-0  标题-2字              频率-2  标题-3字  \
# 0     29.0       cable   23.0  cable management    7.0
# 1     27.0       stars   22.0        five stars    2.0
# 2     26.0       great    7.0       great cable    NaN
# 3     23.0  management    6.0      easy install    NaN
# 4     22.0        five    5.0        four stars    NaN
# ..     ...         ...    ...               ...    ...
# 252    NaN         NaN    NaN               NaN    NaN
# 253    NaN         NaN    NaN               NaN    NaN
# 254    NaN         NaN    NaN               NaN    NaN
# 255    NaN         NaN    NaN               NaN    NaN
# 256    NaN         NaN    NaN               NaN    NaN
#
#                        频率-4  评论-1字      频率-6  评论-2字              频率-8  评论-3字  \
# 0    great cable management     57      desk   25.0  cable management    3.0
# 1     cable management tool     47    cables   19.0      easy install    3.0
# ...

# %%
sss = list(dff.columns)
sss[1::2],sss[0::2] = sss[0::2],sss[1::2]

# %%
sss
# Out:
# ['频率-0',
#  '标题-1字',
#  '频率-2',
#  '标题-2字',
#  '频率-4',
#  '标题-3字',
#  '频率-6',
#  '评论-1字',
#  '频率-8',
#  '评论-2字',
#  '频率-10',
#  '评论-3字']

# %%
dff.columns = sss

# %%
dff.head()
# Out:
#    频率-0       标题-1字  频率-2             标题-2字  频率-4                   标题-3字  \
# 0  29.0       cable  23.0  cable management   7.0  great cable management
# 1  27.0       stars  22.0        five stars   2.0   cable management tool
# 2  26.0       great   7.0       great cable   NaN                     NaN
# 3  23.0  management   6.0      easy install   NaN                     NaN
# 4  22.0        five   5.0        four stars   NaN                     NaN
#
#    频率-6   评论-1字  频率-8             评论-2字  频率-10                    评论-3字
# 0    57    desk  25.0  cable management    3.0  cable management system
# 1    47  cables  19.0      easy install    3.0     product easy install
# 2    40   cable  11.0       power strip    2.0    cable management easy
# 3    39   great   9.0     great product    2.0       placed power strip
# 4    37    easy   7.0   surge protector    2.0        desk easy install
