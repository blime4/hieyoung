# %%
import numpy as np
import pandas as pd
import os
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from gensim import corpora, models
import gensim
from nltk.util import ngrams 
import emoji
from itertools import chain
paths = "./dataset/"

# %%
def get_one_two_three(selects):
    global All_selects
    thgrams_selects = {}
    bigrams_selects = {}
    selects_token ={}
    for select in selects:
        tokenizer = RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(select)
        tokens = [i for i in tokens if(i.lower() not in stopwords.words('english'))]
        bigrams_t = ngrams(tokens, 2) 
        thgrams_t = ngrams(tokens, 3)
        tokens = list(set(tokens))
        bigrams_t = list(set(bigrams_t))
        thgrams_t = list(set(thgrams_t))
        for t in thgrams_t:
            t = str(t).split("'")
            t = t[1] +" "+ t[3]+" "+t[5]
            if t not in thgrams_selects:
                thgrams_selects[t] = 1
            else:
                thgrams_selects[t] += 1
        for b in bigrams_t:
            b = str(b).split("'")
            b = b[1]+" "+b[3]
            if b not in bigrams_selects:
                bigrams_selects[b] = 1
            else:
                bigrams_selects[b] += 1
        for token in tokens:
            if token not in selects_token:
                selects_token[token] = 1
            else:
                selects_token[token] += 1
    df_selects_token = pd.DataFrame.from_dict(selects_token,orient="index",columns=["频率"]).sort_values(by="频率",ascending=False)
    df_selects_token = df_selects_token[df_selects_token["频率"]>=3]
    df_bigrams_selects = pd.DataFrame.from_dict(bigrams_selects,orient="index",columns=["频率"]).sort_values(by="频率",ascending=False)
    df_bigrams_selects = df_bigrams_selects[df_bigrams_selects["频率"]>=2]
    df_thgrams_selects = pd.DataFrame.from_dict(thgrams_selects,orient="index",columns=["频率"]).sort_values(by="频率",ascending=False)
    df_thgrams_selects = df_thgrams_selects[df_thgrams_selects["频率"]>=2]
    return df_selects_token,df_bigrams_selects,df_thgrams_selects

# %%
def get_df_out(titles,comments):
    df_titles_token,df_bigrams_titles,df_thgrams_titles = get_one_two_three(titles)
    df_comments_token,df_bigrams_comments,df_thgrams_comments = get_one_two_three(comments)
    df_titles_token['标题-1字']=df_titles_token.index
    df_titles_token = df_titles_token.reset_index(drop=True)
    df_bigrams_titles['标题-2字']=df_bigrams_titles.index
    df_bigrams_titles = df_bigrams_titles.reset_index(drop=True)
    df_thgrams_titles['标题-3字']=df_thgrams_titles.index
    df_thgrams_titles = df_thgrams_titles.reset_index(drop=True)
    df_comments_token['评论-1字']=df_comments_token.index
    df_comments_token = df_comments_token.reset_index(drop=True)
    df_bigrams_comments['评论-2字']=df_bigrams_comments.index
    df_bigrams_comments = df_bigrams_comments.reset_index(drop=True)
    df_thgrams_comments['评论-3字']=df_thgrams_comments.index
    df_thgrams_comments = df_thgrams_comments.reset_index(drop=True)
    if df_titles_token.empty:
        df_t = pd.DataFrame()
    elif df_bigrams_titles.empty:
        df_t = df_titles_token
    elif df_thgrams_titles.empty:
        df_t = pd.concat([df_titles_token,df_bigrams_titles],axis=1)
    else:
        df_t = pd.concat([df_titles_token,df_bigrams_titles,df_thgrams_titles],axis=1)
    if df_thgrams_comments.empty:
        df_c = pd.concat([df_comments_token,df_bigrams_comments],axis=1)
    else:
        df_c = pd.concat([df_comments_token,df_bigrams_comments,df_thgrams_comments],axis=1)
    df_out = pd.concat([df_t,df_c],axis=1)
    return df_out

# %%
def change_coloum(df):
    df.columns = [x+"-"+str(i) if x=="频率" else x for i,x in enumerate(df.columns)]
    a,b,c = [],[],[]
    for i,j in enumerate(list(df.columns)):
        if i%2==0:
            a.append(j)
        else:
            b.append(j)
    for i in range(int(len(list(df.columns))/2)):
        c.append(b[i])
        c.append(a[i])
    df = df[c]
    return df

# %%
df_tmp = pd.DataFrame()
for _,_,files in os.walk(paths):
    print(files)
writer = pd.ExcelWriter("final.xlsx")
all_titles = []
all_comments = []
for file in files:
    keyname = file.split("-")[0]
    path = paths+file
    df = pd.read_excel(path)
    df = df[["标题","内容"]]
    titles = []
    comments = []
    df.标题.apply(lambda x:titles.append(x))
    df.内容.apply(lambda x:comments.append(x))
    titles = [emoji.demojize(str(i)).lower() for i in titles]
    comments = [emoji.demojize(str(i)).lower() for i in comments]
    all_titles.append(titles)
    all_comments.append(comments)
    df_out = get_df_out(titles,comments)
    df_out = change_coloum(df_out)
    df_out.to_excel(writer,sheet_name=keyname+"-"+str(len(df)),index=None)
df_out = get_df_out(list(chain.from_iterable(all_titles)),list(chain.from_iterable(all_comments)))
df_out = change_coloum(df_out)
df_out.to_excel("all_titles_comments.xlsx",sheet_name="所有标题和评论词频汇总",index=None)
#     print(df_out.columns)
writer.close()
test = pd.read_excel("final.xlsx",None)
writer = pd.ExcelWriter("final-out.xlsx")
for key in test.keys():
    pd_out = test[key]
    pd_out = pd_out.head(100)
    pd_out.to_excel(writer,sheet_name=key,index=None)
writer.close()
# Out:
# ['9178905931-US-Reviews-201015.xlsx', 'B07HMZNMCK-US-Reviews-201015.xlsx', 'B07HN2KV6J-US-Reviews-201015.xlsx', 'B07Q5W52DT-US-Reviews-201015.xlsx', 'B07Q9QN4J8-US-Reviews-201015.xlsx', 'B07XQD5R5D-US-Reviews-201015.xlsx', 'B085M96XGX-US-Reviews-201015.xlsx']

# %%
file = "带抽屉款.xlsx"
path = paths+file
df = pd.read_excel(path)
df = df[["标题","内容"]]
titles = []
comments = []
df.标题.apply(lambda x:titles.append(x))
df.内容.apply(lambda x:comments.append(x))
titles = [emoji.demojize(str(i)).lower() for i in titles]
comments = [emoji.demojize(str(i)).lower() for i in comments]
all_titles.append(titles)
all_comments.append(comments)
df_out = get_df_out(titles,comments)

df_out = change_coloum(df_out)
df_out
# Out:
#            标题-1字    频率-0            标题-2字   频率-2                   标题-3字  \
# 0          great  1807.0       five stars  805.0       easy put together
# 1      organizer  1097.0    great product  345.0    great desk organizer
# 2          stars   877.0    easy assemble  344.0     mesh desk organizer
# 3           five   805.0   desk organizer  331.0    easy assemble sturdy
# 4           desk   792.0  great organizer  289.0  perfect desk organizer
# ...          ...     ...              ...    ...                     ...
# 27563        NaN     NaN              NaN    NaN                     NaN
# 27564        NaN     NaN              NaN    NaN                     NaN
# 27565        NaN     NaN              NaN    NaN                     NaN
# 27566        NaN     NaN              NaN    NaN                     NaN
# 27567        NaN     NaN              NaN    NaN                     NaN
#
#         频率-4     评论-1字    频率-6           评论-2字    频率-8                 评论-3字  \
# 0      145.0      easy  2620.0   easy assemble  1181.0     easy put together
# 1       86.0      desk  2489.0    put together  1165.0  easy assemble sturdy
# 2       44.0     great  1766.0        easy put   807.0   put together sturdy
# 3       25.0  together  1539.0  desk organizer   354.0   super easy assemble
# 4       25.0       put  1495.0   great product   273.0  sturdy easy assemble
# ...      ...       ...     ...             ...     ...                   ...
# 27563    NaN       NaN     NaN             NaN     NaN  plenty storage price
# 27564    NaN       NaN     NaN             NaN     NaN    price better could
# 27565    NaN       NaN     NaN             NaN     NaN  storage price better
# 27566    NaN       NaN     NaN             NaN     NaN     looks good plenty
# 27567    NaN       NaN     NaN             NaN     NaN  expected really easy
#
#        频率-10
# 0        795
# 1        127
# 2         90
# 3         77
# 4         65
# ...      ...
# 27563      3
# 27564      3
# 27565      3
# 27566      3
# 27567      3
#
# [27568 rows x 12 columns]

# %%
df_good = pd.DataFrame()
df_bad = pd.DataFrame()
df_none = pd.DataFrame()
for file in files:
    keyname = file.split("-")[0]
    path = paths+file
    df = pd.read_excel(path)
    df = df[["标题","内容","星级"]]
    df.loc[df["星级"].isnull(),"星级"] = 0
    df_good = pd.concat([df_good,df[df["星级"]>=4]])
    df_bad = pd.concat([df_bad,df[df["星级"].isin([1,2,3])]])
    df_none = pd.concat([df_none,df[df["星级"]==0]])
good_titles = [emoji.demojize(str(i)).lower() for i in df_good["标题"].to_list()]
good_comments = [emoji.demojize(str(i)).lower() for i in df_good["内容"].to_list()]
bad_titles = [emoji.demojize(str(i)).lower() for i in df_bad["标题"].to_list()]
bad_comments = [emoji.demojize(str(i)).lower() for i in df_bad["内容"].to_list()]
none_titles = [emoji.demojize(str(i)).lower() for i in df_none["标题"].to_list()]
none_comments = [emoji.demojize(str(i)).lower() for i in df_none["内容"].to_list()]

# %%
writer = pd.ExcelWriter("star-rating.xlsx")
good_df_out = get_df_out(good_titles,good_comments)
good_df_out.columns = [x+"-"+str(i) if x=="频率" else x for i,x in enumerate(good_df_out.columns)]
good_df_out = good_df_out[['标题-1字','频率-0','标题-2字','频率-2', '标题-3字', '频率-4','评论-1字','频率-6','评论-2字','频率-8','评论-3字','频率-10']]
good_df_out.to_excel(writer,sheet_name="好评-"+str(len(good_df_out)),index=None)
bad_df_out = get_df_out(bad_titles,bad_comments)
bad_df_out.columns = [x+"-"+str(i) if x=="频率" else x for i,x in enumerate(bad_df_out.columns)]
bad_df_out = bad_df_out[['标题-1字','频率-0','标题-2字','频率-2', '评论-1字','频率-4','评论-2字','频率-6','评论-3字','频率-8']]
bad_df_out.to_excel(writer,sheet_name="差评-"+str(len(bad_df_out)),index=None)
# none_df_out = get_df_out(none_titles,none_comments)
# none_df_out.columns = [x+"-"+str(i) if x=="频率" else x for i,x in enumerate(none_df_out.columns)]
# none_df_out = none_df_out[['标题-1字','频率-0','标题-2字','频率-2','评论-1字','频率-4','评论-2字','频率-6']]
# none_df_out.to_excel(writer,sheet_name="未评价-"+str(len(none_df_out)),index=None)
# good_bad_none_all = pd.concat([good_df_out,bad_df_out,none_df_out])
good_bad_none_all = pd.concat([good_df_out,bad_df_out])
df_tmp1 = good_bad_none_all[["频率-0","标题-1字"]].groupby("标题-1字").sum().sort_values(by="频率-0",ascending=False).reset_index()
df_tmp2 = good_bad_none_all[["频率-2","标题-2字"]].groupby("标题-2字").sum().sort_values(by="频率-2",ascending=False).reset_index()
df_tmp3 = good_bad_none_all[["频率-4","标题-3字"]].groupby("标题-3字").sum().sort_values(by="频率-4",ascending=False).reset_index()
df_tmp4 = good_bad_none_all[["频率-6","评论-1字"]].groupby("评论-1字").sum().sort_values(by="频率-6",ascending=False).reset_index()
df_tmp5 = good_bad_none_all[["频率-8","评论-2字"]].groupby("评论-2字").sum().sort_values(by="频率-8",ascending=False).reset_index()
df_tmp6 = good_bad_none_all[["频率-10","评论-3字"]].groupby("评论-3字").sum().sort_values(by="频率-10",ascending=False).reset_index()
df_all_temp = pd.concat([df_tmp1,df_tmp2,df_tmp3,df_tmp4,df_tmp5,df_tmp6],axis=1)
df_all_temp.to_excel(writer,sheet_name="汇总-"+str(len(good_bad_none_all)),index=None)
df_all = pd.DataFrame()
for file in files:
    keyname = file.split("-")[0]
    path = paths+file
    df = pd.read_excel(path)
    df = df[["标题","内容","星级"]]
    df_all = pd.concat([df_all,df])
df_all.sort_values(by="星级",ascending=False,inplace=True)
df_all.to_excel(writer,sheet_name="标题-评论-星级汇总-"+str(len(df_all)),index=None)
writer.close()

# %%
a = []
b = []
for i,j in enumerate(list(good_df_out.columns)):
    if i%2==0:
        a.append(j)
    else:
        b.append(j)
c = []
for i in range(int(len(list(good_df_out.columns))/2)):
    
    c.append(b[i])
    c.append(a[i])
c
# Out:
# ['频率-0',
#  '标题-1字',
#  '频率-2',
#  '标题-2字',
#  '频率-4',
#  '标题-3字',
#  '频率-6',
#  '评论-1字',
#  '频率-8',
#  '评论-2字',
#  '频率-10',
#  '评论-3字']

# %%
good_titles
# Out:
# ['easy to assemble looks great on my desk',
#  'exactly as advertised',
#  'lo recomiendo',
#  'very nice',
#  'helps my son a lot!',
#  'helps me keep very organized at work !!',
#  'just right',
#  'perfect',
#  'i love this!!',
#  'organized and aesthetically pleasing!',
#  'great looking!',
#  'good for work stations',
#  'good organization',
#  'great organizer!!!',
#  'great product!',
#  'great buy',
#  'perfect fit',
#  'review',
#  'sturdy',
#  'nice system',
#  'just what i needed.',
#  'great storage rack',
#  'i am so glad i purchased it.  it has good storage and file holderss',
#  'lots of storage space!',
#  'good in a pinch',
#  'love, love, love!',
#  'very affordable',
#  'great price',
#  'great organization!',
#  'perfect for virtual learning',
#  'nice little desktop organizer. very easy to assemble.',
#  'desk storage',
#  'joliebonde',
#  'very good',
#  'love it!!!',
#  'perfect',
#  'practical',
#  'missing parts',
#  'perfect desk addition!',
#  'a good quality',
#  'nice and sturdy',
#  'very nice',
#  'lo util q es para organizar un buro de oficina',
#  'great',
#  'just what was needed!',
#  'holds a lot of different school supplies. thank',
#  'great organization',
#  'exactly what i want',
#  'great price',
#  'great organizer!',
#  'easy to put together',
#  'exactly what i needed.',
#  'organization',
#  'sturdy',
#  'perfect for small area',
#  'good quality',
#  'just as shown',
#  'fantastic for home office',
#  'easy and simple',
#  'yes',
#  'desk organizer',
#  'perfect fit',
#  'happy with purchase',
#  'easy to assemble and great organizer',
#  'organizing superstar',
#  'great organization',
#  'easy to assemble and sturdy',
#  'easy to assemble',
#  'keep my things tidy and organized',
#  'great desktop organizer',
#  'simplehouseware mesh desk organizer with sliding drawer',
#  'helps keep you organized',
#  'perfect for homeschool!',
#  'great organizer',
#  'sturdy',
#  'five stars!',
#  'it worked for me',
#  'sturdy',
#  'exactly as advertised-good product',
#  'great desk organizer',
#  'nice & neat',
#  'sturdy',
#  '=)',
#  'good product',
#  'organized',
#  'good for organizing',
#  'great organization',
#  'i like it',
#  'easy to assemble.',
#  'compact but holds everything we need',
#  'great for distance learning!',
#  'e learning',
#  'satisfied',
#  'desk organizer delivered on time without problems.',
#  'easy to assembly and is very sturdy',
#  'easy to assemble and provide a lot of storage space',
#  'this has appeased the teenager',
#  'multiple use organizer',
#  'good  quality and sturdy.',
#  'good buy!',
#  'exactly what was needed',
#  'great!',
#  'awesome!',
#  'does what it should',
#  'works well',
#  'gets you organized',
#  'perfect',
#  'good',
#  'useful',
#  'help with my mess',
#  'nice unit',
#  'just what we needed',
#  'home office here i come!',
#  'virtual learning',
#  'very sturdy',
#  'good product',
#  'debility',
#  "it's good",
#  'needs a little tweeking',
#  'great for getting organized!',
#  'sturdy',
#  'perfect to keep 1st graders organized at home',
#  'small desk, perfect fit',
#  'great value and price.  money well spent.',
#  'satisfied',
#  'es muy fácil de armar, buen espacio de almacenamiento y muy madizo',
#  'sturdy keeps everything organized',
#  'great product!',
#  'perfect for distance learning organization',
#  'simplicity and organizational',
#  'worth the money.',
#  'lots of storage',
#  'amazing organizer!',
#  'great buy!',
#  'great sturdy organizer',
#  'it’s good.',
#  'very functional',
#  'read people',
#  'great organizer for desk',
#  'very good',
#  'great so far!',
#  'happy',
#  'lightweight but sturdy.',
#  'it is light weight but sturdy.',
#  'organization is key',
#  'just what i needed to get organized',
#  'noisy drawer',
#  'great buy',
#  'easy to set up and surprisingly stron',
#  'great organization for home office',
#  'perfect organizer for a home office',
#  'looks slightly worn but should be functional',
#  'great functionality!',
#  'exactly as described.',
#  'very well made!',
#  'love this!',
#  'great organizer!',
#  'works great for at home school',
#  'buen producto',
#  'nice organizer!',
#  'arrived kinda bent but i fixed it :thumbs_up:',
#  'great product!!!',
#  'it was the prefect fit to my desk',
#  'helps from home',
#  'i love it!',
#  'desk organization',
#  'great organizer',
#  'perfect for staying organized during remote learning!',
#  'great desk organizer',
#  'i recommend this item.',
#  'easy and quick to put together very sturdy love it very much.',
#  'good for virtual learning workspace',
#  'looks sturdy and size is perfect for small desk.',
#  'as described',
#  'love',
#  'organization!',
#  'good storage space',
#  'very nice',
#  'organizer',
#  'good',
#  'arrived as advertised',
#  'great buy',
#  'perfect',
#  'love it',
#  'perfect organizer',
#  'great organizer',
#  'love it',
#  'nice',
#  "i'd buy again.",
#  'just what we needed',
#  'perfect for the at home students',
#  'good product helped me organize home office',
#  'easy assembly, pretty sturdy',
#  'perfect desk organizer',
#  'little hulk organizer',
#  'great',
#  'nice for the price:microphone::woman_dancing:',
#  'as described...',
#  'very happy review',
#  'perfect for sorting and storage',
#  'quick and easy setup',
#  'works',
#  'very nice and easy to assemble',
#  'space saver',
#  'love it!',
#  'great for organizing school stuff',
#  'large space and good quality',
#  'very nice',
#  'perfect gunplay station',
#  'a must buy for working at home',
#  'organized at last',
#  'o',
#  'it’s good to know that when i order an item, it actually is what it’s adverts',
#  'needing organization',
#  'very nice and sturdy',
#  'seems ok so far',
#  'metal is twisted',
#  'good item',
#  'perfect',
#  'good space organizer',
#  'amazing!!',
#  'nice organizer',
#  'simple and easy at low cost',
#  'perfect',
#  'great organizer for desk',
#  'just what i needed',
#  'love it!',
#  'well made good price',
#  'assembly required',
#  'great organizer',
#  'love it!!',
#  'space saver!',
#  'ease of assembling',
#  'multifunctional and compact!',
#  'feeling organized.',
#  'very happy with product.',
#  'perfect',
#  'easy assembly',
#  'ship as scheduled',
#  'very sturdy',
#  'exactly what i was looking for',
#  'see my desk now',
#  'clean.',
#  'great product!',
#  'great organization',
#  'good storage space',
#  'love it',
#  'i like how you can design it your own way.',
#  'good deal',
#  'desk organizer',
#  'great organizer',
#  'perfect item',
#  'compact and space saving',
#  'great for school organization',
#  'great orgnaizer',
#  'easy to put together',
#  'very efficient',
#  'will do captain',
#  'keeps my paperwork nice and neat!!',
#  'put the white thingy  in first, then put the black one into the white one',
#  'best office storage device',
#  'nice desk organizer',
#  'sturdy and compact.',
#  'great!',
#  'love this! 10/10 purchase',
#  'great for home office!',
#  'as described. helped tidy up desk.',
#  'keeps  things organized',
#  'handles a lot of desk essentials',
#  'being organized while remote.',
#  'buy some glue',
#  'perfect storage for a smaller desk',
#  'as promised only better',
#  'great product to keep me organized',
#  'perfect size',
#  'very easy to assemble',
#  'n/a',
#  'product was as advertised!',
#  'perfect for on top of my desk',
#  'good',
#  'love it',
#  'plenty of storage',
#  'helpful for organizing, easy to put together!',
#  ':red_heart_selector:',
#  'love it',
#  'great all in one organizer',
#  'great product at a great price!',
#  'it’s perfect for what i need.',
#  'solid purchase',
#  'value, sturdy, get it.',
#  'desk organizer',
#  'satisfaction',
#  'good deal',
#  'classes up my 5 year old’s art station',
#  'very nice',
#  'perfect!',
#  'very satisfied',
#  'got what i wanted',
#  'works well if you don\'t use the plastic "connectors"',
#  'office supplies',
#  'tiny plugs are very hard to get in for assembly but a beaut once assembled. strong.  clean lines.',
#  'great product',
#  'perfect for home office',
#  'lots of storage!',
#  'great!',
#  'great for make up',
#  'holds a ton of stuff, great size',
#  'great design',
#  'the perfect all-in-one desktop organizer!!!',
#  'just right',
#  'quick shipping, easy to assemble',
#  'great product',
#  'great product!',
#  'easy to assemble',
#  'useful',
#  'assemble!',
#  "it's a great organizer!!",
#  'easy to assemble',
#  'good experience with seller.',
#  '"a place for everything and everything in it\'s place!"',
#  'absolutely recommend!',
#  'very useful',
#  'organizer',
#  'worth the price',
#  'good product',
#  'much appreciated books/supplies organizer!',
#  'love it',
#  'sturdy and unobtrusive',
#  'good',
#  'space saving desk organizer',
#  'great space saver!',
#  'fixed the folder/letter tray wiggling issue and end up happy with your purchase.',
#  'sturdy and worth it',
#  'timely shipping',
#  'makeup on the go',
#  'make sure you follow the directions when putting the file folders in.',
#  'easy to put together',
#  'works for my needs',
#  'nice with a little help',
#  'good desktop file organizer',
#  'price',
#  'great organization tool',
#  'functional',
#  'easy to use but the top hangers. i had to use zip ties to hold down',
#  'really useful',
#  'exactly what i expected',
#  'great for small places',
#  'nice desk top organizer',
#  'very satisfied!',
#  'classroom storage',
#  'holds more files',
#  'its has good storage',
#  'excellent product',
#  'highly recommend',
#  'it’s perfect!!',
#  'helps keep me organized',
#  'it’s good',
#  'organizational',
#  'helpful desk organizing tool',
#  'must have',
#  'exactly what i was looking for',
#  '4.9/5. sturdy, easy to build, and great price.',
#  'a great organizer!',
#  'love it! worth the price',
#  'great storage item!',
#  'super',
#  'decent',
#  'love it!',
#  'easy to assemble',
#  'good for the price',
#  'good quality',
#  'home office',
#  ':thumbs_up_medium-light_skin_tone:',
#  'great product',
#  'weighs more than 1 pound that is stated in the discription',
#  'great organizational tool',
#  'decent desk organizer',
#  'it’s a good product to help keep you organized.  will likely buy another one for another area.',
#  'classic and simple',
#  'great',
#  'like it',
#  'it made everything look tidy on my desk.',
#  'stack up',
#  'office supply',
#  'awesome',
#  'great value',
#  'easy to put together',
#  'nice product',
#  'great organizer',
#  'great organizer',
#  'it was easy to assemble and looked like the photo.',
#  'nice',
#  'easy to assemble and good with storage',
#  'lots of storage and the drawer move easily',
#  'good',
#  'great',
#  'great product!',
#  'perfect',
#  'easy to build',
#  'good',
#  'great',
#  'good buy!',
#  'great for the home office!',
#  'good got the money.',
#  'elegant design, easy to assemble and disassemble',
#  'this is exactly what i was looking for',
#  'thumbs up',
#  'easy organization',
#  'perfect',
#  'solid desk addition with space for lots',
#  'great office addition',
#  'perfect organizer',
#  'amazing!!!',
#  'organizer',
#  'great value and nice file organizer for the office',
#  'great organizer',
#  'very good',
#  'very good',
#  'love this',
#  'looks great',
#  'happy',
#  'great space saver',
#  'worth the money!',
#  'perfect',
#  '%100',
#  'buy this!',
#  'my office',
#  'compact organizer',
#  'hi',
#  'great product',
#  'desk organizer',
#  'desk top storage unit',
#  'very nice',
#  'great addition',
#  'just what i needed.',
#  'sturdy',
#  'very nice product',
#  'very pleased',
#  'great organizer!',
#  'staying organized',
#  'got 3, now way more organized and clean',
#  'efficient',
#  'great product',
#  'great organizational product',
#  'best desk organizer!!!',
#  'awesome',
#  'good sturdy product.',
#  'holds my stuff',
#  'keeps my mess nice n neat',
#  'love it',
#  'perfect',
#  'great item, especially for the price',
#  'love it',
#  'great item',
#  'perfect for my home office',
#  'perfect office item.',
#  'space is great',
#  'perfect',
#  'great desk organization',
#  'ample storage and sturdy',
#  'nice organizer',
#  'highly recommend',
#  'very nice!',
#  'average size foot print with lots of vertical storage space.',
#  'excellent product, would recommend!',
#  'great way to get organized!',
#  'great organizer!',
#  'great organizer',
#  'does what i need perfection',
#  'easy peasy',
#  'multiple storage options',
#  'good product does-is what you expect could be better but good',
#  'lots of storage',
#  'fantastic item for home office.',
#  'well worth the price.',
#  'compact and easy to assemble',
#  'storage',
#  'exactly as pictured',
#  'two thumbs up',
#  'solid',
#  'arrived quickly',
#  'great',
#  'very good product.',
#  'clean your clutter!',
#  'perfect for charging station',
#  ':thumbs_up_light_skin_tone:',
#  'perfect desk organizer',
#  'perfect way to organize your clutter!',
#  'easy and great!',
#  'it doesn’t occupy much space',
#  'perfect for desk organization!',
#  'looks good and organizes the clutter',
#  'a must for those looking for a lot of functional storage/organization',
#  'it worked far as what i needed',
#  'put together correctly and it works fine!',
#  'easy assembly',
#  'stay organized',
#  'easy',
#  'great product',
#  'just what i wanted!',
#  'works for me',
#  'all- in- one - desk organizer.',
#  'love it. good size but not too big.',
#  'organizer',
#  'organizer',
#  'legit',
#  'organizer',
#  'good',
#  'great for at-home office',
#  'as advertised',
#  'work from home 2020!!',
#  'organization',
#  'awesome product',
#  'great product',
#  'does the job!',
#  'great desk organizer for anyone who is working from home.',
#  'i love it so much!!!',
#  'sturdy!!',
#  'great piece for the desk',
#  'great',
#  'it’s a very good product.',
#  'great!',
#  'as advertised',
#  'a must have for home office',
#  'buy it',
#  'just what i needed!!!',
#  'great purchase',
#  'great',
#  'good',
#  'great space saver',
#  'good storage capacity !',
#  'it is a quality product.',
#  'exactly as described. great product.',
#  'great storage but flimsy',
#  'love this',
#  'perfect for storing tablet  and stuff',
#  'perfect',
#  'best desk organizer',
#  'desk organizer',
#  'i happy with it.',
#  'great buy!',
#  'really nice storage',
#  'base is great, top slots not so much.',
#  'happy',
#  'perfect',
#  'great!',
#  'love it',
#  'that you all make great products for us that have our offices organized.',
#  'easy to assemble and sturdy',
#  'like this product',
#  ':thumbs_up_medium_skin_tone:',
#  'i like it',
#  'organize',
#  'easy to put together',
#  'easy to assemble',
#  'love this product',
#  'sturdy, lots of room',
#  'it’s great for storage the shelves are not as tight as i would like',
#  'sturdy and easy to assemble',
#  'excellent!',
#  'it’s easy to put together',
#  'great product!',
#  'i am satisfied and will recommend to others.',
#  'spot on!',
#  'amazing',
#  'office trays',
#  'efficient',
#  'nice organization.',
#  'great organizer',
#  'great',
#  'handy paperwork organizer!',
#  'great',
#  'very compacted',
#  'great office addition',
#  'love it!',
#  'title',
#  'organized',
#  'great desktop organizer,',
#  'great organizer',
#  'sturdy',
#  'simple yet effective organizer.',
#  'perfection',
#  'this totally organized my table!',
#  'exactly what i was looking for!',
#  "it's sturdy and strong -- lots of storage areas",
#  'great stiliff',
#  'does its job',
#  'great product',
#  'affordable!',
#  'great use',
#  'easy to assemble',
#  'perfectly organized & sturdy to boot!',
#  'space saver',
#  'easy way to organize',
#  "unit works well for what i need, problem w/chipped paint on 3 pcs & feet don't fit well at bottom.",
#  'good quality',
#  'nice organizer',
#  'great!',
#  'perfect for my home office',
#  'functional + sturdy',
#  'office center',
#  'just right.',
#  'just what i wanted',
#  'sturdy. product as described',
#  'organization made simple',
#  'would recommend ordering this',
#  'perfdct',
#  'accurately described',
#  'perfect size',
#  'great product',
#  'nice product',
#  'perfect!',
#  'love it',
#  'exactly what i needed!',
#  'convenient',
#  'great desk organizer!',
#  'exactly what was needed for working at home',
#  'great',
#  'quality',
#  'my desk helper',
#  'love!',
#  'great for organizing',
#  'instructions was easy to understand and it was easy to assemble.',
#  'sturdy and spacious',
#  'racks tip over with any weight applied',
#  'perfect size',
#  'neatness counts',
#  'perfect for my needs',
#  'compact & sturdy',
#  'mesh miracle',
#  'holds a lot',
#  'great organizing tool for our at home school/work.',
#  'works well',
#  'attractive',
#  '@',
#  'love it!',
#  'very strong and keeps my desk looking neat.',
#  'love it!',
#  'very sturdy!',
#  'i have no complaints',
#  'very useful',
#  'good',
#  'sturdy and easy to put together',
#  'lots of space',
#  'handy and efficient.',
#  'great organizer !',
#  'product reflect ad',
#  'valued product',
#  "it's very functional",
#  'good buy!',
#  'perfect for college student',
#  'as expected',
#  'excellent product',
#  'love this holder!',
#  'it’s sturdy and works well.',
#  'just what i was looking for !',
#  'good storage',
#  'worth more than the price suggests...',
#  'desk top organizer',
#  'love it',
#  'great organizer',
#  'easy to assemble',
#  'works perfect !!',
#  'i love it!',
#  'great product for the price!',
#  'fit the bill',
#  'product',
#  "i'm satisfied with this product",
#  'useful',
#  'just what i needed...',
#  'sturdy',
#  'perfect',
#  'it’s perfect!',
#  'perfect for what i needed',
#  'great product',
#  'freed up a lot of desk space!',
#  'meets the need',
#  ':thumbs_up:',
#  'great addition to my new home office!',
#  'very easy to assemble, perfect for my family of 6.',
#  'easy to assemble!',
#  'i love it!',
#  'great storage',
#  'fulfilled my expectations',
#  'love it!',
#  'na',
#  'desk storage',
#  'worked great!',
#  'it’s ok',
#  'such a great organizer',
#  'great product',
#  'read the instructions',
#  'wonderful all in one desk storage solution',
#  'good value',
#  'had to buy zip ties.',
#  'organizes desktop.',
#  'definitely recommend!',
#  'great desk organizer',
#  'great desk organizer',
#  'as expected',
#  'easy to assemble & very sturdy',
#  '3 cubbyholes = 5 uprights',
#  'excellent purchase',
#  'nice organizer for the home office',
#  'nice sturdy and great organizer',
#  'great for organization of school subjects',
#  'easy organization.',
#  'worth the money',
#  'perfect for my home office!',
#  'great product',
#  'drawer',
#  'perfect for home office',
#  'wonderful purchase',
#  ':thumbs_up:',
#  'be sure and push pins down that hold file folders in place',
#  'having the different departments',
#  'good basic file holder',
#  'perfect for small office',
#  'super easy to put together',
#  'great desk organizer',
#  'good for the home office.',
#  'sturdiness and storage capacity',
#  'perfect',
#  '-',
#  'perfect piece',
#  'decent storage unit and design for organizing',
#  'great for the price.',
#  'exactly what i was hoping for',
#  'organize things',
#  ':smiling_face_with_smiling_eyes:',
#  'great organizer!',
#  'very nice',
#  'great product',
#  'this is amazing keep everything organized',
#  'perfect',
#  'good product',
#  'great organizer',
#  'exactly what i wanted',
#  'i like',
#  'awesome',
#  'perfect for my desk',
#  'perfect for desk',
#  'generous storage. sturdy. easy to use.',
#  'nice sturdy organizer',
#  'just what i needed!',
#  'very happy',
#  'sturdy organizer with a pull out drawer',
#  'must have!',
#  'great',
#  'good purchase',
#  'love it',
#  'cheaper at kmart',
#  'organization',
#  'easy to assemble',
#  'works well',
#  'great product',
#  'easy to assemble, holds a lot of books',
#  'super helpful',
#  'simple',
#  'great item',
#  'perfect',
#  'better than expected',
#  'sturdy, easy to assemble',
#  'get it',
#  'great organization piece for my desk.',
#  'exactly what i needed',
#  'good buy',
#  'neat and tidy',
#  'great organizer',
#  'great item after my modifications.',
#  "does exactly what it's designed to do.",
#  'great desk storage',
#  'sturdy and nice looking!',
#  'great organization',
#  'exactly as shown.',
#  'great',
#  'worth the money',
#  'desk organizer',
#  'as advertised',
#  'great organizer',
#  'space',
#  'good buy',
#  'convient',
#  'great organizer',
#  'great compact storage',
#  'good buy',
#  'office ready',
#  'a must have for your desk',
#  'great organizational abilities!',
#  'perfect size and well built!',
#  'great buy!',
#  'love',
#  'space',
#  'love it',
#  'great product',
#  'great!!!',
#  'great item',
#  'love, love, love!',
#  'perfect!',
#  'organization. yes!',
#  'good product',
#  'sturdy ample size storage bins',
#  'excellent must have',
#  'great',
#  'fabulous',
#  'thank you!!!',
#  'works good',
#  "it's sturdy",
#  'fills the bill',
#  'no problems',
#  'nice',
#  'very sturdy',
#  'nice',
#  'quality',
#  'space saver',
#  'perfect desk organizer',
#  'bible  organizer. no more cluterred mess.',
#  'great product, great price',
#  'pretty good',
#  'such a space saver',
#  'quick to assemble and good quality :thumbs_up:',
#  'great product',
#  'awesome',
#  'very handy on desk',
#  'it holds up!',
#  "it's sturdy and easy to assemble.",
#  'adds a lot of storage to any area',
#  'easy to assemble',
#  'perfect!',
#  'awesome',
#  'easy to assemble',
#  'nailed it',
#  'the best',
#  'easy to assemble!',
#  'was as advertised',
#  'good buy!',
#  'great',
#  'very practical',
#  'the best!',
#  'mesh desk organizer',
#  'great storage',
#  'love my caddy',
#  'works great',
#  'everything in it’s place.  meets my needs.',
#  'as what i expected',
#  'improved my organization.',
#  'good product, exactly as described.  nice looking.',
#  'as advertised',
#  'easy and great for desk',
#  'neat desk',
#  'does the job... very well!!',
#  'met my needs',
#  'great buy',
#  'worth it if you like organization',
#  'easy to organized',
#  'very happy with my purchase.',
#  'perfect',
#  'easy to assemble',
#  'drawer pulls out all the way.. so be careful',
#  'great organizer!',
#  'great price!',
#  'good job',
#  'great organization',
#  'small, sturdy and good storage organization.',
#  'lots of storage',
#  'love it',
#  'exactly as pictured and expected.',
#  'great for organization!',
#  'this worked well!',
#  'good product',
#  'keep your stuff organized for a clean desk!',
#  'very easy too assemble.',
#  'good desk organizer',
#  'good value!',
#  'this is a very sturdy, well designed storage tray.',
#  'easy to assemble',
#  'good sturdy rack.',
#  'great!',
#  'well made, strong unit!',
#  'awesome!',
#  'got this for my office and use it everyday.',
#  'must buy',
#  'it was very handy for all my needs',
#  'mesh desk storage unit is  a hit',
#  'great organizer!',
#  'do not lose hardware!',
#  'it’s perfect.',
#  'sturdy',
#  'like',
#  'good quality',
#  'works as expected.',
#  'office administrator',
#  'good',
#  'after my wife received hers, i bought one for myself.',
#  'great find!',
#  'easy to assemble',
#  'quality',
#  'retuning 1st one i got',
#  'perfect',
#  'great product',
#  'horrible putting it together',
#  'quality.',
#  'what you see is what you get',
#  'works well',
#  'well executed product; functional use of space',
#  'not too large for a small desk.',
#  'space saving multipurpose desk organizer',
#  'great product',
#  'sturdy.',
#  'what i needed.',
#  'great storage option for your desk',
#  'useful and for a good price',
#  'as described',
#  'our desk looks more organized',
#  'great',
#  'does the job!',
#  'organized storage for the desk at its best',
#  'sturdy',
#  'this is a great product!',
#  'is a good organizer',
#  'met all my expectations',
#  'desk organization',
#  'neat and easy to use.',
#  'great little organizer',
#  'exactly what i needed',
#  'design/layout is perfect fit 4 small desk',
#  'great product!',
#  'nice office organizer',
#  'my file',
#  'good and easy',
#  'great buy!',
#  'perfect for desktop',
#  'awesome organizer',
#  '5 stars for students',
#  'simple and sturdy',
#  'desk organizer',
#  'would definitely purchase again!',
#  'good product',
#  'good buy!',
#  'keeps everything organized',
#  'perfec!',
#  'meets desktop organization needs and is easy to assemble.',
#  'fast delivery',
#  'these work.',
#  'handy and compact for your organizing needs!',
#  'it’s important to know that i have more work space',
#  'just as described',
#  'just what was needed',
#  'great organizer',
#  'excellent organizational piece!',
#  'good organizer',
#  'great orgnizer',
#  'good design. functional',
#  'amazing find!',
#  'nice organizer',
#  'decent',
#  'great for office',
#  'great',
#  'amazing',
#  'perfect for small desks',
#  'compact organizatiom',
#  'nightstand use',
#  'fantastic',
#  'easy to assemble',
#  'organization',
#  'super organized',
#  'review',
#  'great organization addition to office.',
#  'exactly what i was in need of.',
#  'this desk organizer is very helpful',
#  'best ever for office!',
#  'organizer',
#  'meets the need',
#  'great desk organizer!',
#  "my cats don't knock this over",
#  'great product',
#  'great product',
#  'great product',
#  'good organizer',
#  'disappointed',
#  'desk organizer',
#  'no holes in back to feed charging cords through gotta cut your own',
#  "it's exactly what i wanted.",
#  'got my desk organized instantly',
#  'mesh deck rocks',
#  'great desk organizer',
#  'perfect!!',
#  'would purchase again',
#  'organize',
#  'ok',
#  'great!',
#  'just as shown',
#  'great product',
#  'love it. very useful and keeps you organized!',
#  'easy',
#  'useful organizer',
#  'lots of storage space',
#  'great',
#  'really quick service',
#  'waw, like what i want.',
#  ...]

# %%
list(good_df_out.columns)
# Out:
# ['标题-1字',
#  '频率-0',
#  '标题-2字',
#  '频率-2',
#  '标题-3字',
#  '频率-4',
#  '评论-1字',
#  '频率-6',
#  '评论-2字',
#  '频率-8',
#  '评论-3字',
#  '频率-10']

# %%
def change_coloum(df):
    a,b,c = [],[],[]
    for i,j in enumerate(list(df.columns)):
        if i%2==0:
            a.append(j)
        else:
            b.append(j)
    for i in range(int(len(list(df.columns))/2)):
        c.append(b[i])
        c.append(a[i])
    df = df[c]
    return df

# %%
good_df_out
# Out:
#        标题-1字   频率-0          标题-2字   频率-2                标题-3字  频率-4   评论-1字  \
# 0      great  357.0    plant stand  118.0    great plant stand  17.0   great
# 1      plant  197.0     five stars  114.0    easy put together  10.0   plant
# 2      stand  187.0  great product   48.0  perfect plant stand  10.0   stand
# 3     sturdy  172.0   plant stands   42.0   sturdy plant stand   7.0  sturdy
# 4       nice  163.0    looks great   35.0     nice plant stand   7.0    easy
# ...      ...    ...            ...    ...                  ...   ...     ...
# 2310     NaN    NaN            NaN    NaN                  NaN   NaN     NaN
# 2311     NaN    NaN            NaN    NaN                  NaN   NaN     NaN
# 2312     NaN    NaN            NaN    NaN                  NaN   NaN     NaN
# 2313     NaN    NaN            NaN    NaN                  NaN   NaN     NaN
# 2314     NaN    NaN            NaN    NaN                  NaN   NaN     NaN
#
#        频率-6             评论-2字  频率-8                评论-3字  频率-10
# 0     510.0       plant stand   216    easy put together   85.0
# 1     490.0     easy assemble   156  super easy assemble   22.0
# 2     390.0      put together   114  easy assemble looks   16.0
# 3     374.0      plant stands    91     love plant stand   13.0
# 4     328.0       looks great    90       super easy put   12.0
# ...     ...               ...   ...                  ...    ...
# 2310    NaN     timely manner     2                  NaN    NaN
# 2311    NaN  product provides     2                  NaN    NaN
# 2312    NaN         well wish     2                  NaN    NaN
# 2313    NaN      pots flowers     2                  NaN    NaN
# 2314    NaN     quickly seems     2                  NaN    NaN
#
# [2315 rows x 12 columns]

# %%
change_coloum(good_df_out)
# Out:
#        频率-0   标题-1字   频率-2          标题-2字  频率-4                标题-3字   频率-6  \
# 0     357.0   great  118.0    plant stand  17.0    great plant stand  510.0
# 1     197.0   plant  114.0     five stars  10.0    easy put together  490.0
# 2     187.0   stand   48.0  great product  10.0  perfect plant stand  390.0
# 3     172.0  sturdy   42.0   plant stands   7.0   sturdy plant stand  374.0
# 4     163.0    nice   35.0    looks great   7.0     nice plant stand  328.0
# ...     ...     ...    ...            ...   ...                  ...    ...
# 2310    NaN     NaN    NaN            NaN   NaN                  NaN    NaN
# 2311    NaN     NaN    NaN            NaN   NaN                  NaN    NaN
# 2312    NaN     NaN    NaN            NaN   NaN                  NaN    NaN
# 2313    NaN     NaN    NaN            NaN   NaN                  NaN    NaN
# 2314    NaN     NaN    NaN            NaN   NaN                  NaN    NaN
#
#        评论-1字  频率-8             评论-2字  频率-10                评论-3字
# 0      great   216       plant stand   85.0    easy put together
# 1      plant   156     easy assemble   22.0  super easy assemble
# 2      stand   114      put together   16.0  easy assemble looks
# 3     sturdy    91      plant stands   13.0     love plant stand
# 4       easy    90       looks great   12.0       super easy put
# ...      ...   ...               ...    ...                  ...
# 2310     NaN     2     timely manner    NaN                  NaN
# 2311     NaN     2  product provides    NaN                  NaN
# 2312     NaN     2         well wish    NaN                  NaN
# 2313     NaN     2      pots flowers    NaN                  NaN
# 2314     NaN     2     quickly seems    NaN                  NaN
#
# [2315 rows x 12 columns]

# %%
df_good = pd.DataFrame()
df_bad = pd.DataFrame()
df_none = pd.DataFrame()
file = files[2]
keyname = file.split("-")[0]
path = paths+file
df = pd.read_excel(path)
df = df[["标题","内容","星级"]]
df.loc[df["星级"].isnull(),"星级"] = 0
df_good = df[df["星级"]>=4]
df_bad = df[df["星级"].isin([1,2,3])]
df_none = df[df["星级"]==0]
good_titles = [emoji.demojize(str(i)).lower() for i in df_good["标题"].to_list()]
good_comments = [emoji.demojize(str(i)).lower() for i in df_good["内容"].to_list()]
bad_titles = [emoji.demojize(str(i)).lower() for i in df_bad["标题"].to_list()]
bad_comments = [emoji.demojize(str(i)).lower() for i in df_bad["内容"].to_list()]
none_titles = [emoji.demojize(str(i)).lower() for i in df_none["标题"].to_list()]
none_comments = [emoji.demojize(str(i)).lower() for i in df_none["内容"].to_list()]

writer = pd.ExcelWriter("star-rating"+keyname+".xlsx")
good_df_out = get_df_out(good_titles,good_comments)
good_df_out.columns = [x+"-"+str(i) if x=="频率" else x for i,x in enumerate(good_df_out.columns)]
good_df_out = good_df_out[['标题-1字','频率-0','标题-2字','频率-2', '标题-3字', '频率-4','评论-1字','频率-6','评论-2字','频率-8','评论-3字','频率-10']]
good_df_out.to_excel(writer,sheet_name="好评-"+str(len(good_df_out)),index=None)
bad_df_out = get_df_out(bad_titles,bad_comments)
bad_df_out.columns = [x+"-"+str(i) if x=="频率" else x for i,x in enumerate(bad_df_out.columns)]
bad_df_out = bad_df_out[['频率-0','评论-1字','频率-2','评论-2字']]
bad_df_out.to_excel(writer,sheet_name="差评-"+str(len(bad_df_out)),index=None)
# none_df_out = get_df_out(none_titles,none_comments)
# none_df_out.columns = [x+"-"+str(i) if x=="频率" else x for i,x in enumerate(none_df_out.columns)]
# none_df_out = none_df_out[['标题-1字','频率-0','标题-2字','频率-2','评论-1字','频率-4','评论-2字','频率-6']]
# none_df_out.to_excel(writer,sheet_name="未评价-"+str(len(none_df_out)),index=None)
# good_bad_none_all = pd.concat([good_df_out,bad_df_out,none_df_out])
good_bad_none_all = pd.concat([good_df_out,bad_df_out])
df_tmp1 = good_bad_none_all[["频率-0","标题-1字"]].groupby("标题-1字").sum().sort_values(by="频率-0",ascending=False).reset_index()
df_tmp2 = good_bad_none_all[["频率-2","标题-2字"]].groupby("标题-2字").sum().sort_values(by="频率-2",ascending=False).reset_index()
df_tmp3 = good_bad_none_all[["频率-4","标题-3字"]].groupby("标题-3字").sum().sort_values(by="频率-4",ascending=False).reset_index()
df_tmp4 = good_bad_none_all[["频率-6","评论-1字"]].groupby("评论-1字").sum().sort_values(by="频率-6",ascending=False).reset_index()
df_tmp5 = good_bad_none_all[["频率-8","评论-2字"]].groupby("评论-2字").sum().sort_values(by="频率-8",ascending=False).reset_index()
df_tmp6 = good_bad_none_all[["频率-10","评论-3字"]].groupby("评论-3字").sum().sort_values(by="频率-10",ascending=False).reset_index()
df_all_temp = pd.concat([df_tmp1,df_tmp2,df_tmp3,df_tmp4,df_tmp5,df_tmp6],axis=1)
df_all_temp.to_excel(writer,sheet_name="汇总-"+str(len(good_bad_none_all)),index=None)
df_all = pd.DataFrame()
for file in files:
    keyname = file.split("-")[0]
    path = paths+file
    df = pd.read_excel(path)
    df = df[["标题","内容","星级"]]
    df_all = pd.concat([df_all,df])
df_all.sort_values(by="星级",ascending=False,inplace=True)
df_all.to_excel(writer,sheet_name="标题-评论-星级汇总-"+str(len(df_all)),index=None)
writer.close()

# %%
files[2]
# Out:
# '悬挂款.xlsx'

# %%
bad_df_out
# Out:
#    频率-0  评论-1字  频率-2          评论-2字
# 0     3  would     2      table top
# 1     3    top     2       able use
# 2     3  table     2  thought would
